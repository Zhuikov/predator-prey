# %%
import ppmodel
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 1500, 1500, 35, 178)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
plt.plot(np.arange(0, len(grass)), grass,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
#plt.ylim(0, 250)
#plt.xlim(0, 500)
plt.legend(loc=1)
plt.show()

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 400, 100, 35, 9000)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
plt.plot(np.arange(0, len(grass)), grass,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 800)
plt.xlim(0, 1500)
plt.legend(loc=2)
plt.show()

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 10, 108, 58, 2)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
#plt.plot(np.arange(0, len(grass0)), grass0,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 200)
plt.xlim(1000, 4000)
plt.legend(loc=1)
plt.show()

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 10, 208, 58, 7690)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
#plt.plot(np.arange(0, len(grass0)), grass0,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 500)
plt.xlim(1000, 4000)
plt.legend(loc=1)
plt.show()

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 10, 108, 30, 21)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
#plt.plot(np.arange(0, len(grass0)), grass0,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 500)
plt.xlim(1000, 4000)
plt.legend(loc=1)
plt.show()

# %%
pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 10, 208, 24, 149)

plt.plot(np.arange(0, len(prey)), prey, 'b', label="Preys")
plt.plot(np.arange(0, len(pred)), pred, 'r', label="Predators")
#plt.plot(np.arange(0, len(grass0)), grass0,'g',label="Grass")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 1250)
plt.xlim(2000, 5000)
plt.legend(loc=1)
plt.show()
