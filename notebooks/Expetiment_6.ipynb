# %%
import ppmodel


pred, prey, grass, result = ppmodel.start_model('L', 100, 100, 1, 4200, 75, 35, 2)

# %%
prey0 = prey[100:len(prey) - 500]
pred0 = pred[100:len(pred) - 500]

plt.plot(np.arange(0, len(prey0)), prey0, label="Preys")
plt.plot(np.arange(0, len(pred0)), pred0, label="Predators")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 250)
plt.xlim(0, 15000)
plt.legend(loc=1)
plt.show()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

prey1 = prey[8800:10500]
pred1 = pred[8800:10500]

plt.plot(np.arange(0, len(prey1)), prey1, label="Preys")
plt.plot(np.arange(0, len(pred1)), pred1, label="Predators")
plt.ylabel("Number")
plt.xlabel("Step")
plt.ylim(0, 180)
plt.legend(loc=2)
plt.show()

# %%
import math
prey2_1 = prey[8800:9100]
pred2_1 = pred[8800:9100]

prey2_2 = prey[9100:9410]
pred2_2 = pred[9100:9410]

prey2_3 = prey[9410:9900]
pred2_3 = pred[9410:9900]


plt.plot(prey2_1, pred2_1, 'g')
plt.plot(prey2_2, pred2_2, 'b')
plt.plot(prey2_3, pred2_3, 'r')
plt.ylabel("Predators")
plt.xlabel("Preys")
plt.xlim(20, 140)
plt.ylim(0, 18)
#plt.plot(np.arange(0, len(pred2)), pred)
plt.show()
